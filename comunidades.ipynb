# %%
import geopandas as gpd
import pandas as pd

nombre = 'EXTREMADURA'
provincias = ['CACERES', 'BADAJOZ']

comunidad = pd.concat([gpd.read_file(f'FINALES/{x}') for x in provincias])

# %%
comunidad.drop_duplicates('geometry', inplace=True)

# %%
comunidad
# Out:
#              ID                            NOMBRE formato  anho  \
# 0      11762007  PNOA-2023-EXT-240-4328-NPC01.LAZ     LAZ  2023
# 1      11762008  PNOA-2023-EXT-240-4329-NPC01.LAZ     LAZ  2023
# 2      11762009  PNOA-2023-EXT-240-4330-NPC01.LAZ     LAZ  2023
# 3      11762010  PNOA-2023-EXT-240-4331-NPC01.LAZ     LAZ  2023
# 4      11762011  PNOA-2023-EXT-240-4332-NPC01.LAZ     LAZ  2023
# ...         ...                               ...     ...   ...
# 22349  11761683  PNOA-2023-EXT-764-4231-NPC01.LAZ     LAZ  2023
# 22350  11761684  PNOA-2023-EXT-764-4232-NPC01.LAZ     LAZ  2023
# 22351  11761685  PNOA-2023-EXT-764-4233-NPC01.LAZ     LAZ  2023
# 22352  11761686  PNOA-2023-EXT-764-4234-NPC01.LAZ     LAZ  2023
# 22353  11761687  PNOA-2023-EXT-764-4235-NPC01.LAZ     LAZ  2023
#
#                  densidad tamanho  coord_x  coord_y  ORIG_SRID  \
# 0      Densidad 5 Ptos/m2   42.02   240000  4328000      25830
# 1      Densidad 5 Ptos/m2   57.02   240000  4329000      25830
# ...

# %%
comunidad.to_file(f'FINALES/{nombre}')
